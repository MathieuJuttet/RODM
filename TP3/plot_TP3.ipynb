# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv("alpha_015_y_indegree.txt", " ")
df1.head()
df1.plot(x = 'pagerank', y= 'indegree', kind='scatter', logx= True)

# %%
df2 = pd.read_csv("alpha_015_y_outdegree.txt", " ")
df2.head()
df2.plot(x = 'pagerank', y= 'outdegree', kind='scatter', logx= True)

# %%
df3 = pd.read_csv("double_page_rank_015_01.txt", " ")
df3.head()
df3.plot(x = 'pagerank_015', y= 'pagerank_01', kind='scatter', logx= True, logy= True)

# %%
df3 = pd.read_csv("double_page_rank_015_02.txt", " ")
df3.head()
df3.plot(x = 'pagerank_015', y= 'pagerank_02', kind='scatter', logx= True, logy= True)

# %%
df3 = pd.read_csv("double_page_rank_015_05.txt", " ")
df3.head()
df3.plot(x = 'pagerank_015', y= 'pagerank_05', kind='scatter', logx= True, logy= True)

# %%
df3 = pd.read_csv("double_page_rank_015_09.txt", " ")
df3.head()
df3.plot(x = 'pagerank_015', y= 'pagerank_09', kind='scatter', logx= True, logy= True)
